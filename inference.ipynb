# %%
from ultralytics import YOLO

# %%
model = YOLO("Training/runs/detect/train3/weights/best.pt")

# %%
a=model.predict("input.mp4",save=True)
print(a[0])

for x in a[0].boxes:
    print(x)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) c:\Users\Dev\Desktop\Football Analysis\input.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 47.3ms
# video 1/1 (frame 2/750) c:\Users\Dev\Desktop\Football Analysis\input.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 54.6ms
# video 1/1 (frame 3/750) c:\Users\Dev\Desktop\Football Analysis\input.mp4: 384x640 1 goalkeeper, 18 players, 3 referees, 61.1ms
# ...
